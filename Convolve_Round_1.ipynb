# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/PRATHAM/Downloads/Dataset.csv')
df.head()
# Out:
#    Unnamed: 0   x_1  x_109  x_113  x_12  x_124  x_127  x_144  x_16  x_18  ...  \
# 0           0  5099      1      5   156     35     -2      1    40   999  ...
# 1           1  5191      0      1   164     16      1      5     4   999  ...
# 2           2  5228      1      0   774     75      1      5    12   999  ...
# 3           3  5228      1      1   747      4      1      5    69   999  ...
# 4           4  5196      1      5    29     28      0      4    32   999  ...
#
#    x_73  x_77  x_78  x_8  x_80  x_83  x_89  x_91  x_99  y
# 0  0.11   629    14  487 -0.31   115  0.02 -0.10 -0.49  0
# 1  0.11   509    26  346 -0.31   317  0.02  0.24 -0.21  0
# 2  0.11  1058    30  227 -0.31   464  0.02 -0.10 -0.21  0
# 3  0.11  1048     4   17 -0.31    39 -0.18 -0.10 -0.21  0
# 4  0.11   993    22   58 -0.31   492  0.02 -0.10  0.21  0
#
# [5 rows x 42 columns]

# %%
df.shape
# Out:
# (4119, 42)

# %%
df.describe()
# Out:
#         Unnamed: 0          x_1        x_109        x_113         x_12  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean   2059.000000  5166.469289     0.563244     3.048798   503.509832
# std    1189.197208    73.588512     0.496044     2.544466   291.454491
# min       0.000000  4964.000000     0.000000     0.000000     0.000000
# 25%    1029.500000  5099.000000     0.000000     1.000000   250.000000
# 50%    2059.000000  5191.000000     1.000000     5.000000   497.000000
# 75%    3088.500000  5228.000000     1.000000     6.000000   760.500000
# max    4118.000000  5228.000000     1.000000     6.000000   999.000000
#
#              x_124        x_127        x_144         x_16         x_18  ...  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000  ...
# mean     50.483855    -0.122845     3.609128    34.826657   960.422190  ...
# std      28.862659     1.468947     1.825079    20.441569   191.922786  ...
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# x_1           0
# x_109         0
# x_113         0
# x_12          0
# x_124         0
# x_127         0
# x_144         0
# x_16          0
# x_18          0
# x_2           0
# x_25          0
# x_27          0
# x_28          0
# x_30          0
# x_33          0
# x_38          0
# x_42          0
# x_44          0
# x_45          0
# x_52          0
# x_55          0
# x_57          0
# x_59          0
# x_60          0
# x_62          0
# x_64          0
# x_67          0
# x_68          0
# x_7           0
# x_70          0
# x_71          0
# x_73          0
# x_77          0
# x_78          0
# x_8           0
# x_80          0
# x_83          0
# x_89          0
# x_91          0
# x_99          0
# y             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 42 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4119 non-null   int64
#  1   x_1         4119 non-null   int64
#  2   x_109       4119 non-null   int64
#  3   x_113       4119 non-null   int64
#  4   x_12        4119 non-null   int64
#  5   x_124       4119 non-null   int64
#  6   x_127       4119 non-null   int64
#  7   x_144       4119 non-null   int64
#  8   x_16        4119 non-null   int64
#  9   x_18        4119 non-null   int64
#  10  x_2         4119 non-null   int64
#  11  x_25        4119 non-null   int64
#  12  x_27        4119 non-null   int64
#  13  x_28        4119 non-null   int64
#  14  x_30        4119 non-null   int64
#  15  x_33        4119 non-null   float64
#  16  x_38        4119 non-null   float64
#  17  x_42        4119 non-null   int64
#  18  x_44        4119 non-null   int64
# ...

# %%
df['y'].value_counts()    #----> Clearly indicating a problem of imbalanced classes
# Out:
# 0    3668
# 1     451
# Name: y, dtype: int64

# %%
columns = df.columns
print(columns)
# Out:
# Index(['Unnamed: 0', 'x_1', 'x_109', 'x_113', 'x_12', 'x_124', 'x_127',
#        'x_144', 'x_16', 'x_18', 'x_2', 'x_25', 'x_27', 'x_28', 'x_30', 'x_33',
#        'x_38', 'x_42', 'x_44', 'x_45', 'x_52', 'x_55', 'x_57', 'x_59', 'x_60',
#        'x_62', 'x_64', 'x_67', 'x_68', 'x_7', 'x_70', 'x_71', 'x_73', 'x_77',
#        'x_78', 'x_8', 'x_80', 'x_83', 'x_89', 'x_91', 'x_99', 'y'],
#       dtype='object')

# %%
column_names = ['x_1', 'x_109', 'x_113', 'x_12', 'x_124', 'x_127',
       'x_144', 'x_16', 'x_18', 'x_2', 'x_25', 'x_27', 'x_28', 'x_30', 'x_33',
       'x_38', 'x_42', 'x_44', 'x_45', 'x_52', 'x_55', 'x_57', 'x_59', 'x_60',
       'x_62', 'x_64', 'x_67', 'x_68', 'x_7', 'x_70', 'x_71', 'x_73', 'x_77',
       'x_78', 'x_8', 'x_80', 'x_83', 'x_89', 'x_91', 'x_99']

# %%
for column in column_names:
    plt.scatter(x = df['y'], y = df[column])
    plt.xlabel('y')  
    plt.ylabel(column)
    plt.title(f'Scatter plot of {column} against y') 
    plt.show()

# %%
new_df = df.drop(columns=['Unnamed: 0','y'], axis=1)
new_df
# Out:
#        x_1  x_109  x_113  x_12  x_124  x_127  x_144  x_16  x_18  x_2  ...  \
# 0     5099      1      5   156     35     -2      1    40   999    7  ...
# 1     5191      0      1   164     16      1      5     4   999    5  ...
# 2     5228      1      0   774     75      1      5    12   999    4  ...
# 3     5228      1      1   747      4      1      5    69   999    3  ...
# 4     5196      1      5    29     28      0      4    32   999    6  ...
# ...    ...    ...    ...   ...    ...    ...    ...   ...   ...  ...  ...
# 4114  5228      1      5   197     82      1      5     6   999    4  ...
# 4115  5228      1      5   949     72      1      5     2   999    6  ...
# 4116  5099      1      1   478     41     -2      1    25   999    1  ...
# 4117  5228      1      0   554     36      1      5    68   999    0  ...
# 4118  5196      1      0   143     26      0      4    21   999    1  ...
#
#       x_71  x_73  x_77  x_78  x_8  x_80  x_83  x_89  x_91  x_99
# ...

# %%
X = df.iloc[:,1:-1].values
y = df.iloc[:,-1].values

# %%
X.shape
# Out:
# (4119, 40)

# %% [markdown]
# ### Normalization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_normalized = scaler.fit_transform(X)

# %% [markdown]
# ### Logistic Regression Model without handling imbalanced classes

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

X_train, X_test, y_train, y_test = train_test_split(X_normalized,y, test_size=0.2, random_state=42)

lr_1 = LogisticRegression()
lr_1.fit(X_train, y_train)
y_pred_1 = lr_1.predict(X_test)

print(classification_report(y_test,y_pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       732
#            1       0.57      0.43      0.49        92
#
#     accuracy                           0.90       824
#    macro avg       0.75      0.70      0.72       824
# weighted avg       0.89      0.90      0.89       824

# %% [markdown]
# ### Logistic Regression Model with Handling Imbalanced Classes

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=1)
X_train_resampled, y_train_resampled = sm.fit_resample(X_train, y_train)

# %%
plt.bar(pd.Series(y_train_resampled).value_counts().index, pd.Series(y_train_resampled).value_counts().values, color='orange', alpha=0.7, label='After SMOTE')

plt.legend()
plt.show()

# %%
lr = LogisticRegression()
lr.fit(X_train_resampled, y_train_resampled)
y_pred = lr.predict(X_test)

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.91       732
#            1       0.43      0.86      0.57        92
#
#     accuracy                           0.86       824
#    macro avg       0.70      0.86      0.74       824
# weighted avg       0.92      0.86      0.87       824

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train_resampled, y_train_resampled)
rfc_pred = rfc.predict(X_test)

print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94       732
#            1       0.56      0.50      0.53        92
#
#     accuracy                           0.90       824
#    macro avg       0.75      0.73      0.74       824
# weighted avg       0.90      0.90      0.90       824

# %%
from sklearn.feature_selection import RFE
rfe = RFE(lr, n_features_to_select=20)
X_train_selected = rfe.fit_transform(X_train_resampled, y_train_resampled)
X_test_selected = rfe.transform(X_test)

#selected_indices = [i for i in range(len(rfe.support_)) if rfe.support_[i]]
#print("Selected feature indices:", selected_indices)

# Train a classification model using the selected features
classifier = xg  # You can replace this with any classifier of your choice
classifier.fit(X_train_selected, y_train_resampled)

# Make predictions on the test set using the selected features
y_pred = classifier.predict(X_test_selected)

print(classification_report(y_test,y_pred))

#feature_names = [f'feature_{i}' for i in range(X.shape[1])]
selected_feature_indices = [i for i in range(len(rfe.support_)) if rfe.support_[i]]
print(selected_feature_indices)
# Get the names of the selected features
selected_feature_names = [column_names[i] for i in selected_feature_indices]
print(selected_feature_names)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       732
#            1       0.51      0.51      0.51        92
#
#     accuracy                           0.89       824
#    macro avg       0.72      0.72      0.72       824
# weighted avg       0.89      0.89      0.89       824
#
# [0, 5, 6, 8, 11, 12, 14, 15, 18, 19, 21, 23, 24, 25, 26, 27, 28, 34, 36, 37]
# ['x_1', 'x_127', 'x_144', 'x_18', 'x_27', 'x_28', 'x_33', 'x_38', 'x_45', 'x_52', 'x_57', 'x_60', 'x_62', 'x_64', 'x_67', 'x_68', 'x_7', 'x_8', 'x_83', 'x_89']

# %%
feature_sel = pd.DataFrame({
    'Variables': column_names,
    'Mark': [1 if feature in selected_feature_names else 0 for feature in column_names]
})

# Save the DataFrame to a CSV file
feature_sel.to_csv('C:/Users/PRATHAM/Desktop/output.csv', index=False)

# %%
feature_sel.shape
# Out:
# (40, 2)

# %%
X_train_resampled.shape

# %%
clf = RandomForestClassifier(random_state=42)

# Fit the model
clf.fit(X_train_resampled, y_train_resampled)

# Get feature importances
feature_importances = clf.feature_importances_

# Get the indices of the top 20 features
top20_indices = feature_importances.argsort()[-20:][::-1]

# Get the names of all features
all_feature_names = [f'feature_{i}' for i in range(X_train_resampled.shape[1])]

# Get the names of the top 20 important features
top20_feature_names = [all_feature_names[i] for i in top20_indices]

# Create a DataFrame with variable names and marks
df = pd.DataFrame({'variables': all_feature_names, 'mark': [1 if feature in top20_feature_names else 0 for feature in all_feature_names]})

# %%
top20_indices

# %%
import xgboost as xgb

# %%
xg = xgb.XGBClassifier()
xg.fit(X_train_resampled, y_train_resampled)
xg_pred = xg.predict(X_test)

print(classification_report(y_test,xg_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       732
#            1       0.50      0.50      0.50        92
#
#     accuracy                           0.89       824
#    macro avg       0.72      0.72      0.72       824
# weighted avg       0.89      0.89      0.89       824

# %%
model = RandomForestClassifier()
model.fit(X_train_resampled, y_train_resampled)

# Get feature importances
feature_importances = model.feature_importances_

# Get the indices of top 20 features
top_20_indices = feature_importances.argsort()[-20:][::-1]

# Get the selected features
selected_features = new_df.columns[top_20_indices]

# %%
selected_features
# Out:
# Index(['x_8', 'x_1', 'x_127', 'x_144', 'x_28', 'x_45', 'x_55', 'x_57', 'x_99',
#        'x_80', 'x_38', 'x_18', 'x_62', 'x_2', 'x_52', 'x_33', 'x_83', 'x_42',
#        'x_77', 'x_44'],
#       dtype='object')

# %%
random_f = pd.DataFrame({
    'Variables': column_names,
    'Mark': [1 if feature in selected_features else 0 for feature in column_names]
})

# Save the DataFrame to a CSV file
random_f.to_csv('C:/Users/PRATHAM/Desktop/rf.csv', index=False)

# %%
random_f
# Out:
#    Variables  Mark
# 0        x_1     1
# 1      x_109     0
# 2      x_113     0
# 3       x_12     0
# 4      x_124     0
# 5      x_127     1
# 6      x_144     1
# 7       x_16     0
# 8       x_18     1
# 9        x_2     1
# 10      x_25     0
# 11      x_27     0
# 12      x_28     1
# 13      x_30     0
# 14      x_33     1
# 15      x_38     1
# 16      x_42     1
# 17      x_44     1
# 18      x_45     1
# 19      x_52     1
# 20      x_55     1
# 21      x_57     1
# 22      x_59     0
# 23      x_60     0
# 24      x_62     1
# 25      x_64     0
# 26      x_67     0
# 27      x_68     0
# 28       x_7     0
# 29      x_70     0
# 30      x_71     0
# 31      x_73     0
# 32      x_77     1
# 33      x_78     0
# 34       x_8     1
# 35      x_80     1
# 36      x_83     1
# 37      x_89     0
# 38      x_91     0
# 39      x_99     1

# %%
import lightgbm as lgb 

lg = lgb.LGBMClassifier()
lg.fit(X_train_resampled, y_train_resampled)
lg_pred = lg.predict(X_test)

print(classification_report(y_test,lg_pred))
# Out:
# [LightGBM] [Info] Number of positive: 2936, number of negative: 2936
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000491 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9299
# [LightGBM] [Info] Number of data points in the train set: 5872, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       732
#            1       0.52      0.54      0.53        92
#
#     accuracy                           0.89       824
#    macro avg       0.73      0.74      0.74       824
# weighted avg       0.90      0.89      0.89       824

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif

# Set the number of features (k)
k = 20
selector = SelectKBest(score_func=mutual_info_classif, k=k)
X_selected = selector.fit_transform(X_train_resampled, y_train_resampled)

# Get the selected features
kbest_features = new_df.columns[selector.get_support()]
kbest_features
# Out:
# Index(['x_1', 'x_113', 'x_124', 'x_127', 'x_16', 'x_2', 'x_25', 'x_28', 'x_38',
#        'x_42', 'x_52', 'x_57', 'x_59', 'x_62', 'x_68', 'x_70', 'x_78', 'x_8',
#        'x_83', 'x_99'],
#       dtype='object')

# %%
kbest = pd.DataFrame({
    'Variables': column_names,
    'Mark': [1 if feature in kbest_features else 0 for feature in column_names]
})

# Save the DataFrame to a CSV file
kbest.to_csv('C:/Users/PRATHAM/Desktop/kbest.csv', index=False)

# %%
kbest
# Out:
#    Variables  Mark
# 0        x_1     1
# 1      x_109     0
# 2      x_113     1
# 3       x_12     0
# 4      x_124     1
# 5      x_127     1
# 6      x_144     0
# 7       x_16     1
# 8       x_18     0
# 9        x_2     1
# 10      x_25     1
# 11      x_27     0
# 12      x_28     1
# 13      x_30     0
# 14      x_33     0
# 15      x_38     1
# 16      x_42     1
# 17      x_44     0
# 18      x_45     0
# 19      x_52     1
# 20      x_55     0
# 21      x_57     1
# 22      x_59     1
# 23      x_60     0
# 24      x_62     1
# 25      x_64     0
# 26      x_67     0
# 27      x_68     1
# 28       x_7     0
# 29      x_70     1
# 30      x_71     0
# 31      x_73     0
# 32      x_77     0
# 33      x_78     1
# 34       x_8     1
# 35      x_80     0
# 36      x_83     1
# 37      x_89     0
# 38      x_91     0
# 39      x_99     1

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector

classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Exhaustive feature selection with limited feature subset size
efs = ExhaustiveFeatureSelector(classifier, min_features=1, max_features=20, scoring='accuracy', cv=2)
efs = efs.fit(X_train_resampled, y_train_resampled)

# Get the selected feature indices
selected_feature_indices = efs.best_idx_

# Get the corresponding feature names
selected_feature_names = [new_df.columns[i] for i in selected_feature_indices]

# Print the selected feature names
print("Selected feature names:", selected_feature_names)

# Transform the original features to the selected subset
X_train_selected = efs.transform(X_train_resampled)
X_test_selected = efs.transform(X_test)

# Train the model on the selected features
classifier.fit(X_train_selected, y_train)

# Make predictions on the test set
y_pred = classifier.predict(X_test_selected)

# Evaluate the performance of the model
print(classification_report(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[54], line 7
#       6 efs = ExhaustiveFeatureSelector(classifier, min_features=1, max_features=20, scoring='accuracy', cv=2)
# ----> 7 efs = efs.fit(X_train_resampled, y_train_resampled)
#       9 # Get the selected feature indices
#
# File ~\anaconda3\lib\site-packages\mlxtend\feature_selection\exhaustive_feature_selector.py:444, in ExhaustiveFeatureSelector.fit(self, X, y, groups, **fit_params)
#     442 parallel = Parallel(n_jobs=n_jobs, pre_dispatch=self.pre_dispatch)
#     443 work = enumerate(
# --> 444     parallel(
#     445         delayed(_calc_score)(
#     446             self,
#     447             X_,
#     448             y,
#     449             list(set(c).union(self.fixed_features_group_set)),
#     450             groups=groups,
# ...
